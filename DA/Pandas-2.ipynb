# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
path = 'C:/Users/2165362/OneDrive - Cognizant/Desktop/Programmes/DataScienceGit/'

# %%
df1 = pd.read_csv(path + 'Resources/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df1')
df2 = pd.read_csv(path + 'Resources/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df2')
df3 = pd.read_csv(path + 'Resources/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df3')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist(bins = 50)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.6)
# Out:
# <Axes: >

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'A', 'B', 'C', 'D'], dtype='object')

# %%
df1.plot.line(x='Unnamed: 0', y='B', figsize=(12,4),lw=1)
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
df1.plot.scatter(x='A',y='B', c='C',cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50)
# Out:
# c:\Users\2165362\OneDrive - Cognizant\Desktop\Programmes\DataScienceGit\dsenv\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>
